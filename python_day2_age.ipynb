# %%
# unit 7 p96~p108

import csv

f = open('age.csv', encoding='UTF-8')  # 파일 여는 내장 함수
data = csv.reader(f)   
result = []                            # 빈 리스트 만들기

for row in data :
    if '신도림' in row[0] :           # '신도림'이 포함된 행정구역 찾기
        for i in row[3:] :            # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
            result.append(int(i))     # 해당 연령의 인구수 리스트에 순서대로 저장하기
print(result)                         # 0세부터 100세 이상까지의 인구수 출력하기
# Out:
# [326, 334, 406, 413, 389, 408, 417, 434, 411, 387, 420, 383, 354, 357, 340, 338, 349, 339, 407, 380, 390, 453, 424, 516, 451, 466, 448, 484, 471, 476, 558, 541, 579, 619, 638, 740, 756, 792, 745, 789, 671, 687, 700, 636, 726, 691, 657, 619, 649, 585, 579, 470, 522, 534, 563, 445, 511, 569, 572, 513, 532, 456, 426, 497, 379, 384, 399, 279, 289, 276, 268, 271, 223, 170, 150, 154, 177, 140, 126, 114, 121, 97, 86, 80, 59, 48, 44, 43, 28, 29, 22, 15, 13, 12, 5, 8, 5, 4, 2, 3, 7]

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')             # 격자 무늬 스타일 지정
plt.plot(result)
plt.show()

# %%
# unit 8 p109~p110

import csv

f = open('age.csv', encoding='UTF-8')  # 파일 여는 내장 함수
data = csv.reader(f)   
result = []  
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요 : ')

if len(name) > 0 :    
    for row in data :
        if name in row[0] :               # 입력받은 지역명이 포함된 행정구역 찾기
            for i in row[3:] :            # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
                #result.append(int(i))
                try:
                    result.append(int(i))     # 해당 연령의 인구수 리스트에 순서대로 저장하기
                except:
                    result.append(int(i.replace(',','')))

    print(result)                         # 0세부터 100세 이상까지의 인구수 출력하기        
else :
    print('인구 구조가 알고 싶은 지역의 이름을 입력하지 않았습니다.')
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요 : 신림동
# [72, 58, 60, 53, 47, 37, 35, 39, 39, 42, 36, 35, 37, 38, 35, 28, 52, 47, 85, 149, 237, 324, 434, 689, 843, 1055, 1155, 1275, 1030, 958, 899, 733, 723, 589, 517, 577, 482, 433, 388, 338, 268, 269, 277, 236, 232, 239, 225, 222, 210, 218, 177, 151, 177, 167, 178, 170, 178, 191, 190, 196, 175, 191, 159, 154, 155, 128, 122, 120, 109, 116, 114, 127, 94, 82, 90, 78, 115, 81, 62, 55, 48, 40, 34, 37, 33, 17, 21, 6, 14, 12, 6, 9, 3, 6, 2, 1, 1, 2, 2, 3, 15]

# %%
import matplotlib.pyplot as plt
if len(name) > 0 :
    plt.style.use('ggplot')                      # 격자 무늬 스타일 지정
    plt.rc('font', family='Malgun Gothic')       #폰트는 맑은 고딕
    plt.title(name+' 지역의 인구 구조')          # 그래프의 제목
    plt.plot(result)
    plt.show()
else :
    print('인구 구조가 알고 싶은 지역의 이름을 입력하지 않았습니다.')
